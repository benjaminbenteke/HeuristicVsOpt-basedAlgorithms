# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot with all points (not only valid points)

# %%
import plotly.graph_objects as go

months = ['Ex1', 'Ex2', 'Ex3', 'Ex4', 'Ex5', 'Ex6',
          'Ex7', 'Ex8', 'Ex9']

fig = go.Figure()

fig.add_trace(go.Bar(
    x=months,
    y=[35.93, 29.39, 25.50, 98.50, 99.10, 58.18, 15.98, 48.90, 15.72],
    name='PVI',
    marker_color='blue'
))

fig.update_layout(
    barmode='group',
    xaxis_title="Examples",
    yaxis_title="Hausdorff distance (HD)",
    showlegend=True
)


# plt.savefig('./hd_PVI.png')
fig.show()

# %%
nubmer_points_list= [100, 200,300,400,500,600,700,800,900,1000,1100,1200, 1300,1400,1500]

# %%
## PDP plots
import json
with open("Ex1Sols.json", "r", encoding="utf-8") as f:
    Ex1Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex1_pdppvi_all= Ex1Sols_loaded["PVI"]["pdp"]
ex1_hdpvi_all= Ex1Sols_loaded["PVI"]["hd"]

with open("Ex2Sols.json", "r", encoding="utf-8") as f:
    Ex2Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex2_pdppvi_all= Ex2Sols_loaded["PVI"]["pdp"]
ex2_hdpvi_all= Ex2Sols_loaded["PVI"]["hd"]

with open("Ex3Sols.json", "r", encoding="utf-8") as f:
    Ex3Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex3_pdppvi_all= Ex3Sols_loaded["PVI"]["pdp"]
ex3_hdpvi_all= Ex3Sols_loaded["PVI"]["hd"]


with open("Ex4Sols.json", "r", encoding="utf-8") as f:
    Ex4Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex4_pdppvi_all= Ex4Sols_loaded["PVI"]["pdp"]
ex4_hdpvi_all= Ex4Sols_loaded["PVI"]["hd"]


with open("Ex5Sols.json", "r", encoding="utf-8") as f:
    Ex5Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex5_pdppvi_all= Ex5Sols_loaded["PVI"]["pdp"]
ex5_hdpvi_all= Ex5Sols_loaded["PVI"]["hd"]


with open("Ex6Sols.json", "r", encoding="utf-8") as f:
    Ex6Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex6_pdppvi_all= Ex6Sols_loaded["PVI"]["pdp"]
ex6_hdpvi_all= Ex6Sols_loaded["PVI"]["hd"]


with open("Ex7Sols.json", "r", encoding="utf-8") as f:
    Ex7Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex7_pdppvi_all= Ex7Sols_loaded["PVI"]["pdp"]
ex7_hdpvi_all= Ex7Sols_loaded["PVI"]["hd"]


with open("Ex8Sols.json", "r", encoding="utf-8") as f:
    Ex8Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex8_pdppvi_all= Ex8Sols_loaded["PVI"]["pdp"]
ex8_hdpvi_all= Ex8Sols_loaded["PVI"]["hd"]


with open("Ex9Sols.json", "r", encoding="utf-8") as f:
    Ex9Sols_loaded = json.load(f)

# ex1_pdppvi_all= Ex1Sols_loaded
ex9_pdppvi_all= Ex9Sols_loaded["PVI"]["pdp"]
ex9_hdpvi_all= Ex9Sols_loaded["PVI"]["hd"]

# %%
#

# %%
# Dark Blue ('#1f77b4')
# Orange ('#ff7f0e')
# Green ('#2ca02c')
# Red ('#d62728')
# Purple ('#9467bd')
# Brown ('#8c564b')
# Pink ('#e377c2')
# Gray ('#7f7f7f')
# Olive ('#bcbd22')

# %%
plt.figure(figsize=(7, 3))
plt.plot(nubmer_points_list, ex1_pdppvi_all,label='Ex1',c= 'black')
plt.plot(nubmer_points_list, ex2_pdppvi_all, label='Ex2',c= 'green')
plt.plot(nubmer_points_list, ex3_pdppvi_all, label='Ex3',c= 'red')
plt.plot(nubmer_points_list, ex4_pdppvi_all, label='Ex4',c= 'magenta')
plt.plot(nubmer_points_list, ex5_pdppvi_all, label='Ex5',c= '#1f77b4')
plt.plot(nubmer_points_list, ex6_pdppvi_all, label='Ex6',c= 'purple')
plt.plot(nubmer_points_list, ex7_pdppvi_all, label='Ex7',c= '#8c564b')
plt.plot(nubmer_points_list, ex8_pdppvi_all, label='Ex8',c= 'olive')
plt.plot(nubmer_points_list, ex9_pdppvi_all, label='Ex9',c= 'gray')


# plt.title('CDF of Uniform Samples vs. Empiricc')
plt.xlabel('Number of starting points')
plt.ylabel('Percentage of distinct points (PDP)')
plt.xticks(nubmer_points_list)
# plt.ylim([0, 1])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('./PVI_pdp.png')
plt.show()

# %%
## HD Plots

# %%
plt.figure(figsize=(7, 3))
plt.plot(nubmer_points_list, ex1_hdpvi_all,label='Ex1',c= 'black')
plt.plot(nubmer_points_list, ex2_hdpvi_all, label='Ex2',c= 'green')
plt.plot(nubmer_points_list, ex3_hdpvi_all, label='Ex3',c= 'red')
plt.plot(nubmer_points_list, ex4_hdpvi_all, label='Ex4',c= 'magenta')
plt.plot(nubmer_points_list, ex5_hdpvi_all, label='Ex5',c= '#1f77b4')
plt.plot(nubmer_points_list, ex6_hdpvi_all, label='Ex6',c= 'purple')
plt.plot(nubmer_points_list, ex7_hdpvi_all, label='Ex7',c= '#8c564b')
plt.plot(nubmer_points_list, ex8_hdpvi_all, label='Ex8',c= 'olive')
plt.plot(nubmer_points_list, ex9_hdpvi_all, label='Ex9',c= 'gray')

# plt.plot([0.5, 1], [0.0, 1], 'r--', label='Uniform CDF')
# plt.title('CDF of Uniform Samples vs. Empiricc')
plt.xlabel('Number of starting points')
plt.ylabel('Hausdorff distance (HD)')
plt.xticks(nubmer_points_list)
# plt.ylim([0, 1])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('./PVI_hd.png')
plt.show()
